# %% [markdown]
# ## Binarni Genetski Algoritam ##
#
#
#
#
# *   Binarni genetski algoritam
# *   Jednotačkasto i dvotačkasto ukrštanje
# *   Mutacija inverzijom i rotacijom
# *   Primeri: sferna i Levijeva funkcija
#
# **Postupak genetskog algoritma:** </br>
# START
# <br>
# Inicijalizacija početne populacije
# <br>
# Računanje funkcije prilagođenosti
# <br>
# Ponavljati: <br>
#
# *   Selekciju
# *   Ukrštanje
# *   Mutaciju
# *   Računanje funkcije prilagođenosti
#
# DOK populacija ne iskonvergira <br>
# STOP<br>

# %% [markdown]
# # 1. Biblioteke
#
# Prvo je neophodno učitati python biblioteke:

# %%
# %matplotlib inline

import random
import numpy as np
import matplotlib.pyplot as plt
import math

from mpl_toolkits import mplot3d

pi = 3.1415

# %% [markdown]
# # 2. Funkcija za kodiranje i dekodiranje hromozoma
#
# Prvo je neophodno jedinku kodirati u odgovarajućoj formi, zavisno od implementacije GA algoritma koji se koristi. U ovom slučaju je neophodno predstaviti je u binarnom obliku.
# Da bismo predstavili realnu vrednost u obliku binarnog broja potrebno je da definišemo preciznost, tj broj bita registra u $n$. Broj različitih vrednost koji se može predstaviti sa tim broj bita je $2^n$, najmanja vrednosti $0$ dok je najveća $2^n -1$.
#
# Nivo diskretizacije
# \begin{equation}
# \Delta=\frac{opseg}{2^n}
# \end{equation}
# pri tome greška koja nastaje je:
# \begin{equation}
# error=\frac{\Delta}{2}
# \end{equation}

# %%
def bin_encode(chromosome, bin_val, min_val, precision):
 #chromosome- vrednost jedne koordinate, nor realna vrednost
 # bin_val- nivo diskretizacije  
 # max_val- minimalnu  vrednost opsega  
 # precision- broj bita za predstavljanje svakog broja
  
  ret = ""
  for g in chromosome:
    val = round((g - min_val)/bin_val)  
    ret += bin(val)[2:].rjust(precision,'0') # transformisemo u binarni broj    
  return ret

def bin_encode_chromosomes(chromosomes, precision, max_val, min_val):
  #chromosomes- ili jedinka 
  # precision- broj bita za predstavljanje svakog broja
  # max_val, min_val- definišemo maksimalnu i minimalnu  vrednost opsega  
  bin_val = (max_val - min_val) / (2**precision-1)  # nivo diskretizicije
  # za svaki hromozom unutar jedinke (npr i za x i y vrednost) pretvaramo u binarni broj
  bin_chromosomes = [ bin_encode(c, bin_val, min_val, precision) for c in chromosomes]
  return bin_chromosomes

# %%
bin_encode_chromosomes([[2, 3]],10,0,10) # test
# Out:
# ['11001100101011001100']

# %% [markdown]
# ## Dekodiranje jedinke
# Vraćanje binarno kodirane jedinke u vrednost realnog broja koja odgovara tako kodiranoj jedincki

# %%
def bin_decode(chromosome, bin_val, min_val, precision):

  ret = []
  for idx in range(0, len(chromosome), precision):
    g = int(chromosome[idx:idx + precision], 2)
    ret.append(g * bin_val + min_val)
    
  return ret

def bin_decode_chromosomes(chromosomes, precision, max_val, min_val):
  
  bin_val = (max_val - min_val) / (2**precision-1) 

  bin_chromosomes = [ bin_decode(c, bin_val, min_val, precision) for c in chromosomes]
  return bin_chromosomes

# %%
bin_decode_chromosomes(['11001100101011001100'],10,0,10)
# Out:
# [[2.0039100684261975, 3.0009775171065494]]

# %% [markdown]
# # 3. Generisanje populacije
# **Početna populacija**
#
# GA započinjemo kreiranjem skupa jedinki koji se naziva populacijom. Svaka jedinka predstavlja potencijalno rešenje.

# %%
def generate_inital_chromosomes(length, max, min, pop_size):
  return [ [random.uniform(min,max) for j in range(length)] for i in range(pop_size)]

def population_stats(costs):
  return costs[0], sum(costs)/len(costs)

# %% [markdown]
# # 4. Funkcije za rangiranje i **selekciju** jedinki
#
# Jedinke se rangiraju (sortiraju) po vrednosti funkcije prilagođenosti funkcijom **rank_chromosomes**.</br>
# Implementirane su sledece vrste selekcija: prirodna i ruletska selekcija. </br>
# Prirodna selekcija je implementirana u  funkciji **natural_selection**, pri čemu ostavljamo samo prvih *n_keep* jedinki.</br>
# Funkcija **roulette_selection** predstavlja ruletski tip selekcije.

# %%
def rank_chromosomes(cost, chromosomes):
  costs = list(map(cost, chromosomes))
  ranked  = sorted( list(zip(chromosomes,costs)), key = lambda c:c[1])
  
  return list(zip(*ranked))

def natural_selection(chromosomes, n_keep):
  return chromosomes[:n_keep]

def roulette_selection(parents):

  pairs = []
  i = 0
  for i in range(0, len(parents), 2):

    weights=[];
    for i in range(len(parents)):
        weights.append((len(parents)-i)*random.random()) #za minimum
      #  weights.append((i+1)*random.random()) #za maksimum
    if (weights[0]>=weights[1]):
        maxInd1=0;
        maxInd2=1;
    else:
        maxInd1=1;
        maxInd2=0;
    
    for i in range(2,len(parents)):
        if weights[i]>weights[maxInd1]:
            maxInd2=maxInd1
            maxInd1=i
        elif weights[i]>weights[maxInd2]:
            maxInd2=1
    pairs.append([parents[maxInd1], parents[maxInd2]])
      
  return pairs

# %% [markdown]
# # 5. Funkcije za  ukrštanje
#
# ## Funkcija za jednotačkasto ukrštanje
# Nasumično biramo jednu tačku ukrštanja. Novi hromozomi h3, h4 će biti sastavljeni od delova ulaznih hromozoma (h1, h2). I to na sledeći način:
#
# * h3 dobija genetski materijal od h1 od početka do  presečne tačke a genetski materijal od h2 dobija od presečne tačke do KRAJA
#
#
# * h4 dobija genetski materijal od h2 od početka do  presečne tačke a genetski materijal od h1 dobija od presečne tačke do KRAJA

# %%
def one_point_crossover(pairs):
  length = len(pairs[0])
  children = []
  
  for (a,b) in pairs:  
   
      r = random.randrange(0, length)
    
      children.append(a[:r] + b[r:])
      children.append(b[:r] + a[r:] )
    
  return children

# %% [markdown]
# ## Funkcija za dvotačkasto ukrštanje
# Nasumično biramo dve tačke ukrštanja. Novi hromozomi h3, h4 će biti sastavljeni od delova ulaznih hromozoma (h1, h2). I to na sledeći način:
#
# * h3 dobija genetski materijal od h1 od početka do prve presečne tačke T1 i od druge presečne tačke T2 do KRAJA
# a genetski materijal od h2 dobija od prve do druge presečne tačke
#
#
# * h4 dobija genetski materijal od h2 od početka do prve presečne tačke i od druge presečne tačke do kraja
# a genetski materijal od h1 dobija od prve do druge presečne tačke

# %%
def two_point_crossover(pairs):
  length = len(pairs[0])
  children = []
  
  for (a,b) in pairs:  
   
      r1 = random.randrange(0, length)
      r2 = random.randrange(0, length)
      
      if r1 < r2:
        children.append(a[:r1] + b[r1:r2] + a[r2:])
        children.append(b[:r1] + a[r1:r2] + b[r2:])
      else:
        children.append(a[:r2] + b[r2:r1] + a[r1:])
        children.append(b[:r2] + a[r2:r1] + b[r1:])
    
  return children

# %% [markdown]
# # 6. Mutacija
#
# # Mutacija inverzijom
#
# Nasumično biramo dve  tačke u hromozomu i genetski materijal koji se nalazi između te dve tačke invertujemo.
#
#
#
# > primer: h = [ 1110101000 ]
# <br>nasumično izabrani indeksi: r1 = 3, r2 = 6
# <br>rezultat nakon mutacije: [1111010000]

# %%
def inv_mutation(chromosomes, mutation_rate):
  mutated_chromosomes = []
  
  for chromosome in chromosomes:
    
    if random.random() < mutation_rate:
      r1 = random.randrange(0, len(chromosome) - 1)
      r2 = random.randrange(0, len(chromosome) - 1)
      
      if r1 < r2:
        mutated_chromosomes.append(chromosome[:r1] + chromosome[r1:r2][::-1] + chromosome[r2:])
      else:
        mutated_chromosomes.append(chromosome[:r2] + chromosome[r2:r1][::-1] + chromosome[r1:])
        
    else:
      mutated_chromosomes.append(chromosome)
      

  return mutated_chromosomes

# %%
inv_mutation(['11001100101011001100'], 0.7)
# Out:
# ['11001100101011001100']

# %% [markdown]
# ## Mutacija rotacijom
#
# Nasumično biramo jednu tačku u hromozomu i genetski materijal koji se nalazi u toj tački invertujemo.
#
# primer: h = [ 1110101000 ]
# nasumično izabrani indeksi: r1 = 3
# rezultat nakon mutacije:  [ 1111101000 ]

# %%
def mutation(chromosomes, mutation_rate):
  mutated_chromosomes = []  
  for chromosome in chromosomes: 

    if random.random() < mutation_rate:
      r1 = random.randrange(0, len(chromosome) - 1)         
      mutated_chromosomes.append( chromosome[:r1]+ str (1-int(chromosome[r1]))+ chromosome[r1+1:]    )        
    else:
      mutated_chromosomes.append(chromosome)
      

  return mutated_chromosomes

# %%
mutation(['11001100101011001100'], 0.9)
# Out:
# ['01001100101011001100']

# %% [markdown]
# # Elitizam
#
# Elitizam omogućava prenos najbolje prilagođenih jedinki iz stare generacije u novu.

# %%
def elitis(chromosomes_old,chromosomes_new, elitis_rate, population_size):
 
  old_ind_size=int(np.round(population_size*elitis_rate))
  return chromosomes_old[:old_ind_size]+chromosomes_new[:(population_size-old_ind_size)]

# %% [markdown]
# # 7. Definicija  funkcije
#
# Definisaćemo funkciju kojoj tražimo optimum (minimum).
#
# ##  Primer 1: Sfera funkcija
#
# Kao prvi primer koristićemo sfernu funkciju koja se definiše na sledeći način
#
#
# \begin{equation}
# f(x, y) = x^2 +y ^2 \\
# \mbox{interval: }  -10 < x, y < 10,\\
# \mbox{minimum: } f(0,0) = 0
# \end{equation}
#
# ##  Primer 2: Levijeva funkcija
# Kao drugi primer koristićemo Levijevu funkciju koja se definiše na sledeći način
#
#
# \begin{equation}
# f(x, y) = sin^2 3πx + (x − 1)^2(1 + sin^2 3πy) + (y − 1)^2(1 + sin^2 2πy) \\
#  \mbox{interval: } -10 < x, y < 10,\\
#   \mbox{minimum: } f(1,1) = 0
# \end{equation}

# %%
def sphera_function(chromosome):
  x = chromosome[0]
  y = chromosome[1] 
  
  tmp1 = math.pow(x, 2)
  tmp2 = math.pow(y, 2)


  return tmp1 + tmp2

# %%
def levy_function(chromosome):
  x = chromosome[0]
  y = chromosome[1] 
  
  tmp1 = math.pow(math.sin(3*pi*x), 2)
  tmp2 = math.pow((x - 1), 2) * (1 + math.pow(math.sin(3*pi*y), 2))
  tmp3 = math.pow((y - 1), 2) * (1 + math.pow(math.sin(2*pi*y), 2))

  return tmp1 + tmp2 + tmp3

# %% [markdown]
# # 7.1. 3D Prikaz funkcije

# %%
def l_show(x, y):
  tmp1 = math.pow(math.sin(3*pi*x), 2)
  tmp2 = math.pow((x - 1), 2) * (1 + math.pow(math.sin(3*pi*y), 2))
  tmp3 = math.pow((y - 1), 2) * (1 + math.pow(math.sin(2*pi*y), 2))

  return tmp1 + tmp2 + tmp3

def s_show(x, y):  
  tmp1 = math.pow(x, 2)
  tmp2 = math.pow(y, 2)
  return tmp1 + tmp2 

levy_vectorized = np.vectorize(l_show)

x = np.linspace(-13, 13, 30)
y = np.linspace(-13, 13, 30)

X, Y = np.meshgrid(x, y)
Z = levy_vectorized(X, Y)

ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='plasma', edgecolor='none')
ax.set_title('Levijeva funkcija');

ax.view_init(50, 35)

# %% [markdown]
# # 8. Main loop - sklopljen genetski algoritam
# - Generišemo početnu populaciju veličine *population_size*
# - Vrtimo glavnu petlju maksimalno *max_iter* puta, pri čemu svaka iteracija petlje predstavlja jednu generaciju
# - Rangiramo jedinke po prilagođenosti, funkcijom **rank_chromosomes**
# - Funkcijom **natural_selection** biramo roditelje (ovo je visak)
# - Funkcijom **bin_encode_chromosomes** kodiramo celu roditeljsku populaciju
# - Funkcijom **roulette_selection** odvajamo parove roditeljskih hromozoma koje ćemo ukrstiti
# - Metodom *dvotačkastog ukrštanja*, tj funkcijom **two_point_crossover** uparujemo roditeljske hromozome i dobijemo populaciju dece
# - Spajamo novonastale hromozome sa roditeljskim u novu populaciju *chromosomes*
# - Na ovoj populaciji vršimo *inverznu mutaciju* funkcijom **inv_mutation** sa zadatim *mutation_rate = 0.3*
# - Dekodiramo celu populaciju funkcijom **bin_decode_chromosomes**
# - Proveravamo da li populacija konvergira ili da li smo došli do optimalnog rešenja
# - Ispisujemo statistike za svaku generaciju: prosečna prilagođenost, najbolji hromozom i sastav najboljeg hromozoma

# %%
def genetic(cost_func , extent, population_size, mutation_rate = 0.8,elitis_rate=0.1, chromosome_length = 2, precision = 13, max_iter = 500):

  min_val = extent[0]
  max_val = extent[1]

  
  avg_list = []
  best_list = []
  curr_best = 10000
  same_best_count = 0
  
  chromosomes = generate_inital_chromosomes(chromosome_length, max_val, min_val, population_size)

  for iter in range(max_iter):
      
    ranked_parents, costs = rank_chromosomes(cost_func, chromosomes)     
    best, average = population_stats(costs)
    parents = natural_selection(ranked_parents, population_size) 
    parents = bin_encode_chromosomes(parents, precision, max_val, min_val)     

    pairs = roulette_selection (parents)       
    children = two_point_crossover(pairs)     
    chromosomes = inv_mutation(children, mutation_rate)
    chromosomes = bin_decode_chromosomes(chromosomes, precision, max_val, min_val)

    ranked_children, costs = rank_chromosomes(cost_func, chromosomes)
    chromosomes=elitis(ranked_parents,ranked_children, elitis_rate, population_size)
    print("Generation: ",iter+1," Average: {:.3f}".format(average)," Curr best: {:.3f}".format(best), 
         "[X, Y] = {:.3f} {:.3f}".format(chromosomes[0][0],chromosomes[0][1]))
    print("-------------------------")
    
    avg_list.append(average)
    if best < curr_best:
      best_list.append(best)
      curr_best = best
      same_best_count = 0
    else:
      same_best_count += 1
      best_list.append(best)
      
    ##
    if (cost_func(chromosomes[0]) < 0.05):
      
      avg_list = avg_list[:iter]
      best_list = best_list[:iter]
      all_avg_list.append(avg_list)
      all_best_list.append(best_list)
      generations_list.append(iter)
     
      print("\nSolution found ! Chromosome content: [X, Y] = {:.3f} {:.3f}\n".format(chromosomes[0][0],chromosomes[0][1]))
      return
        
    if same_best_count > 20:
      print("\nStopped due to convergance.Best chromosome [X, Y] = {:.3f} {:.3f}\n".format(chromosomes[0][0],chromosomes[0][1]))
      
      avg_list = avg_list[:iter]
      best_list = best_list[:iter]
      all_avg_list.append(avg_list)
      all_best_list.append(best_list)
      generations_list.append(iter)
      
      return
    
    if iter == 499:
      avg_list = avg_list[:iter]
      best_list = best_list[:iter]
      all_avg_list.append(avg_list)
      all_best_list.append(best_list)
      generations_list.append(iter)
      
      print("\nStopped due to max number of iterations, solution not found. Best chromosome [X, Y] = {:.3f} {:.3f}\n".format(chromosomes[0][0],chromosomes[0][1]))

# %% [markdown]
# # 9. Iscrtavanje grafikona</br>
# Iscrtavamo prosečnu i najbolji prilagođenost za svaku generaciju.

# %%
def display_stats(all_avg_list, all_best_list, generations_list):
  
  c = 0
  colors = ['red', 'green', 'blue', 'yellow', 'orange']
  
  for average_list in all_avg_list:
      x_axis = list(range(generations_list[c]))
      y_axis = average_list
      plt.plot(x_axis, y_axis, linewidth=3, color=colors[c], label=str(c + 1))
      plt.title('Average cost function value', fontsize=19)
      plt.xlabel('Generation', fontsize=10)
      plt.ylabel('Cost function')
      c += 1
  plt.legend(loc='upper right')
  plt.show()

  c = 0

  for best_list in all_best_list:
      x_axis = list(range(generations_list[c]))
      y_axis = best_list
      plt.plot(x_axis, y_axis, color=colors[c], label=str(c + 1))
      plt.title('Best cost function value', fontsize=19)
      plt.xlabel('Generation')
      plt.ylabel('Cost function')
      c += 1
  plt.legend(loc='upper right')
  plt.show()

# %% [markdown]
# # 10. Konfigurisanje i poziv genetskog algoritma
#
# Argumenti funkcije:
#
#
# 1.   Funkcija za minimizaciju (u našem slučaju Levy_function) - *function*
# 2.   Opseg u kome pretražujemo rešenje - *list*
# 3.   Broj hromozoma (jedinki) - *int*
#
#
# ---
#
# Opcioni argumenti:
#
#
# 4.   Stopa mutacije - *float*
# 5.   Dužina hromozoma - *int*
# 6.   Na koliko decimala kodujemo X i Y - *int*
# 7.   Maksimalni broj iteracija - *int*

# %%
number_of_chromosomes = [20, 100, 150]
all_avg_list = []
generations_list = []
all_best_list = []
run_number = 5

for x in number_of_chromosomes:
  
  print("==========================")
  
  for k in range(0, run_number):
    
    print("\n", k + 1, ": run of genetic algorithm with ", x ," chromosomes.\n")    
    genetic(levy_function, [10, -10], x)
    
  display_stats(all_avg_list, all_best_list, generations_list)
  all_best_list = []
  all_avg_list = []
  generations_list = []
# Out:
# ==========================
#
#  1 : run of genetic algorithm with  20  chromosomes.
#
# Generation:  1  Average: 79.913  Curr best: 1.772 [X, Y] = 0.196 1.062
# -------------------------
# Generation:  2  Average: 25.248  Curr best: 0.580 [X, Y] = 0.353 1.061
# -------------------------
# Generation:  3  Average: 25.936  Curr best: 0.580 [X, Y] = 0.333 1.061
# -------------------------
# Generation:  4  Average: 23.066  Curr best: 0.580 [X, Y] = 0.333 1.061
# -------------------------
# Generation:  5  Average: 24.184  Curr best: 0.580 [X, Y] = 0.333 1.061
# -------------------------
# Generation:  6  Average: 4.563  Curr best: 0.580 [X, Y] = 0.333 1.061
# -------------------------
# Generation:  7  Average: 25.482  Curr best: 0.149 [X, Y] = 0.665 1.061
# -------------------------
# Generation:  8  Average: 18.261  Curr best: 0.149 [X, Y] = 0.665 1.061
# -------------------------
# Generation:  9  Average: 3.901  Curr best: 0.149 [X, Y] = 0.665 1.061
# -------------------------
# Generation:  10  Average: 16.540  Curr best: 0.149 [X, Y] = 0.665 1.061
# -------------------------
# Generation:  11  Average: 40.998  Curr best: 0.149 [X, Y] = 0.665 1.061
# -------------------------
# Generation:  12  Average: 25.022  Curr best: 0.149 [X, Y] = 0.665 1.061
# -------------------------
# Generation:  13  Average: 15.951  Curr best: 0.149 [X, Y] = 0.665 1.061
# -------------------------
# Generation:  14  Average: 28.714  Curr best: 0.149 [X, Y] = 0.665 1.061
# -------------------------
# Generation:  15  Average: 16.482  Curr best: 0.149 [X, Y] = 0.665 1.061
# -------------------------
# Generation:  16  Average: 13.210  Curr best: 0.149 [X, Y] = 0.665 1.061
# -------------------------
# Generation:  17  Average: 13.201  Curr best: 0.149 [X, Y] = 0.665 1.061
# -------------------------
# Generation:  18  Average: 27.854  Curr best: 0.149 [X, Y] = 0.665 1.061
# -------------------------
# Generation:  19  Average: 27.189  Curr best: 0.130 [X, Y] = 0.665 1.041
# -------------------------
# Generation:  20  Average: 8.180  Curr best: 0.130 [X, Y] = 0.665 1.041
# -------------------------
# Generation:  21  Average: 12.719  Curr best: 0.112 [X, Y] = 0.665 1.002
# -------------------------
# Generation:  22  Average: 24.777  Curr best: 0.112 [X, Y] = 0.665 1.002
# -------------------------
# Generation:  23  Average: 16.665  Curr best: 0.112 [X, Y] = 0.665 1.002
# -------------------------
# Generation:  24  Average: 17.983  Curr best: 0.112 [X, Y] = 0.665 1.002
# -------------------------
# Generation:  25  Average: 19.989  Curr best: 0.112 [X, Y] = 0.665 1.002
# -------------------------
# Generation:  26  Average: 7.327  Curr best: 0.112 [X, Y] = 0.665 1.002
# -------------------------
# Generation:  27  Average: 5.561  Curr best: 0.112 [X, Y] = 0.665 1.002
# -------------------------
# Generation:  28  Average: 20.526  Curr best: 0.112 [X, Y] = 0.665 1.002
# -------------------------
# Generation:  29  Average: 36.338  Curr best: 0.112 [X, Y] = 0.665 1.002
# -------------------------
# Generation:  30  Average: 11.591  Curr best: 0.112 [X, Y] = 0.665 1.002
# -------------------------
# Generation:  31  Average: 7.766  Curr best: 0.112 [X, Y] = 0.665 1.002
# -------------------------
# Generation:  32  Average: 4.916  Curr best: 0.112 [X, Y] = 0.665 1.002
# -------------------------
# Generation:  33  Average: 2.033  Curr best: 0.112 [X, Y] = 0.665 1.002
# -------------------------
# Generation:  34  Average: 14.249  Curr best: 0.112 [X, Y] = 0.665 1.002
# -------------------------
# Generation:  35  Average: 18.980  Curr best: 0.112 [X, Y] = 0.665 1.002
# -------------------------
# Generation:  36  Average: 35.414  Curr best: 0.112 [X, Y] = 0.665 1.002
# -------------------------
# Generation:  37  Average: 16.419  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  38  Average: 18.141  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  39  Average: 18.556  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  40  Average: 14.228  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  41  Average: 14.907  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  42  Average: 15.394  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  43  Average: 29.918  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  44  Average: 20.186  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  45  Average: 17.517  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  46  Average: 15.696  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  47  Average: 13.075  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  48  Average: 5.287  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  49  Average: 37.551  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  50  Average: 11.913  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  51  Average: 42.803  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  52  Average: 13.641  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  53  Average: 21.724  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  54  Average: 23.374  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  55  Average: 18.275  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  56  Average: 34.807  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  57  Average: 18.991  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
# Generation:  58  Average: 2.049  Curr best: 0.110 [X, Y] = 1.330 1.002
# -------------------------
#
# Stopped due to convergance.Best chromosome [X, Y] = 1.330 1.002
#
#
#  2 : run of genetic algorithm with  20  chromosomes.
#
# Generation:  1  Average: 100.317  Curr best: 11.253 [X, Y] = 0.822 -1.275
# -------------------------
# Generation:  2  Average: 45.610  Curr best: 3.604 [X, Y] = 0.822 -0.182
# -------------------------
# Generation:  3  Average: 27.285  Curr best: 1.909 [X, Y] = 0.897 0.209
# -------------------------
# Generation:  4  Average: 14.568  Curr best: 1.909 [X, Y] = 0.897 0.209
# -------------------------
# Generation:  5  Average: 18.790  Curr best: 1.221 [X, Y] = 0.853 0.560
# -------------------------
# Generation:  6  Average: 20.146  Curr best: 1.097 [X, Y] = 0.897 1.576
# -------------------------
# Generation:  7  Average: 18.186  Curr best: 0.779 [X, Y] = 0.897 0.795
# -------------------------
# Generation:  8  Average: 9.080  Curr best: 0.779 [X, Y] = 0.897 0.795
# -------------------------
# Generation:  9  Average: 5.227  Curr best: 0.495 [X, Y] = 1.073 0.795
# -------------------------
# Generation:  10  Average: 25.253  Curr best: 0.429 [X, Y] = 0.934 0.795
# -------------------------
# Generation:  11  Average: 10.481  Curr best: 0.429 [X, Y] = 0.934 0.795
# -------------------------
# Generation:  12  Average: 13.583  Curr best: 0.429 [X, Y] = 0.934 0.795
# -------------------------
# Generation:  13  Average: 29.643  Curr best: 0.429 [X, Y] = 0.934 0.795
# -------------------------
# Generation:  14  Average: 16.512  Curr best: 0.378 [X, Y] = 0.934 0.863
# -------------------------
# Generation:  15  Average: 9.979  Curr best: 0.378 [X, Y] = 0.934 0.863
# -------------------------
# Generation:  16  Average: 21.461  Curr best: 0.378 [X, Y] = 0.934 0.863
# -------------------------
# Generation:  17  Average: 27.389  Curr best: 0.378 [X, Y] = 0.934 0.863
# -------------------------
# Generation:  18  Average: 28.592  Curr best: 0.378 [X, Y] = 0.934 0.863
# -------------------------
# Generation:  19  Average: 22.406  Curr best: 0.345 [X, Y] = 0.934 1.019
# -------------------------
# Generation:  20  Average: 12.370  Curr best: 0.345 [X, Y] = 0.934 1.019
# -------------------------
# Generation:  21  Average: 4.554  Curr best: 0.345 [X, Y] = 0.934 1.019
# -------------------------
# Generation:  22  Average: 16.239  Curr best: 0.345 [X, Y] = 0.934 1.019
# -------------------------
# Generation:  23  Average: 3.569  Curr best: 0.345 [X, Y] = 0.934 1.019
# -------------------------
# Generation:  24  Average: 3.352  Curr best: 0.345 [X, Y] = 0.934 1.019
# -------------------------
# Generation:  25  Average: 3.474  Curr best: 0.345 [X, Y] = 0.934 1.019
# -------------------------
# Generation:  26  Average: 30.731  Curr best: 0.345 [X, Y] = 0.934 1.019
# -------------------------
# Generation:  27  Average: 9.984  Curr best: 0.345 [X, Y] = 0.934 1.019
# -------------------------
# Generation:  28  Average: 8.282  Curr best: 0.345 [X, Y] = 0.934 1.019
# -------------------------
# Generation:  29  Average: 25.748  Curr best: 0.345 [X, Y] = 0.934 1.019
# -------------------------
# Generation:  30  Average: 7.203  Curr best: 0.345 [X, Y] = 0.934 1.019
# -------------------------
# Generation:  31  Average: 16.423  Curr best: 0.345 [X, Y] = 0.934 1.019
# -------------------------
# Generation:  32  Average: 17.648  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  33  Average: 5.101  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  34  Average: 21.577  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  35  Average: 8.018  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  36  Average: 25.488  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  37  Average: 22.748  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  38  Average: 29.667  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  39  Average: 14.166  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  40  Average: 19.167  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  41  Average: 12.464  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  42  Average: 7.947  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  43  Average: 13.416  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  44  Average: 9.740  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  45  Average: 4.794  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  46  Average: 26.621  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  47  Average: 19.843  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  48  Average: 19.128  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  49  Average: 23.679  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  50  Average: 18.315  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  51  Average: 7.290  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  52  Average: 9.774  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
# Generation:  53  Average: 16.582  Curr best: 0.320 [X, Y] = 0.621 1.019
# -------------------------
#
# Stopped due to convergance.Best chromosome [X, Y] = 0.621 1.019
#
#
#  3 : run of genetic algorithm with  20  chromosomes.
#
# Generation:  1  Average: 93.007  Curr best: 2.127 [X, Y] = 1.956 1.969
# -------------------------
# Generation:  2  Average: 36.439  Curr best: 2.014 [X, Y] = 1.220 0.236
# -------------------------
# Generation:  3  Average: 21.604  Curr best: 1.102 [X, Y] = 1.339 1.969
# -------------------------
# Generation:  4  Average: 15.744  Curr best: 0.422 [X, Y] = 1.339 1.442
# -------------------------
# Generation:  5  Average: 18.070  Curr best: 0.422 [X, Y] = 1.339 1.442
# -------------------------
# Generation:  6  Average: 4.440  Curr best: 0.413 [X, Y] = 1.334 1.442
# -------------------------
# Generation:  7  Average: 14.107  Curr best: 0.335 [X, Y] = 1.339 1.364
# -------------------------
# Generation:  8  Average: 16.111  Curr best: 0.300 [X, Y] = 1.339 0.739
# -------------------------
# Generation:  9  Average: 14.424  Curr best: 0.300 [X, Y] = 1.339 0.739
# -------------------------
# Generation:  10  Average: 11.150  Curr best: 0.300 [X, Y] = 1.339 0.739
# -------------------------
# Generation:  11  Average: 13.406  Curr best: 0.300 [X, Y] = 1.339 0.739
# -------------------------
# Generation:  12  Average: 17.852  Curr best: 0.290 [X, Y] = 1.332 0.739
# -------------------------
# Generation:  13  Average: 8.627  Curr best: 0.256 [X, Y] = 1.339 1.139
# -------------------------
# Generation:  14  Average: 10.880  Curr best: 0.256 [X, Y] = 1.339 1.139
# -------------------------
# Generation:  15  Average: 9.840  Curr best: 0.201 [X, Y] = 1.339 0.905
# -------------------------
# Generation:  16  Average: 9.326  Curr best: 0.201 [X, Y] = 1.339 0.905
# -------------------------
# Generation:  17  Average: 11.225  Curr best: 0.201 [X, Y] = 1.339 0.905
# -------------------------
# Generation:  18  Average: 25.918  Curr best: 0.201 [X, Y] = 1.339 0.905
# -------------------------
# Generation:  19  Average: 2.247  Curr best: 0.156 [X, Y] = 1.339 1.061
# -------------------------
# Generation:  20  Average: 19.406  Curr best: 0.156 [X, Y] = 1.339 1.061
# -------------------------
# Generation:  21  Average: 10.478  Curr best: 0.137 [X, Y] = 1.339 1.041
# -------------------------
# Generation:  22  Average: 8.830  Curr best: 0.137 [X, Y] = 1.339 1.041
# -------------------------
# Generation:  23  Average: 6.582  Curr best: 0.128 [X, Y] = 1.332 1.041
# -------------------------
# Generation:  24  Average: 18.794  Curr best: 0.027 [X, Y] = 1.017 1.041
# -------------------------
#
# Solution found ! Chromosome content: [X, Y] = 1.017 1.041
#
#
#  4 : run of genetic algorithm with  20  chromosomes.
#
# Generation:  1  Average: 92.878  Curr best: 0.705 [X, Y] = 0.313 0.927
# -------------------------
# Generation:  2  Average: 88.703  Curr best: 0.705 [X, Y] = 0.313 0.927
# -------------------------
# Generation:  3  Average: 68.420  Curr best: 0.705 [X, Y] = 0.313 0.927
# -------------------------
# Generation:  4  Average: 26.665  Curr best: 0.703 [X, Y] = 0.314 0.927
# -------------------------
# Generation:  5  Average: 53.707  Curr best: 0.703 [X, Y] = 0.314 0.927
# -------------------------
# Generation:  6  Average: 46.419  Curr best: 0.703 [X, Y] = 0.314 0.927
# -------------------------
# Generation:  7  Average: 34.500  Curr best: 0.583 [X, Y] = 1.251 0.927
# -------------------------
# Generation:  8  Average: 24.092  Curr best: 0.583 [X, Y] = 1.251 0.927
# -------------------------
# Generation:  9  Average: 35.205  Curr best: 0.583 [X, Y] = 1.251 0.927
# -------------------------
# Generation:  10  Average: 27.665  Curr best: 0.583 [X, Y] = 1.251 0.927
# -------------------------
# Generation:  11  Average: 41.965  Curr best: 0.583 [X, Y] = 1.251 0.927
# -------------------------
# Generation:  12  Average: 22.109  Curr best: 0.583 [X, Y] = 1.251 0.927
# -------------------------
# Generation:  13  Average: 29.683  Curr best: 0.583 [X, Y] = 1.251 0.927
# -------------------------
# Generation:  14  Average: 20.101  Curr best: 0.583 [X, Y] = 1.251 0.927
# -------------------------
# Generation:  15  Average: 18.712  Curr best: 0.583 [X, Y] = 1.251 0.927
# -------------------------
# Generation:  16  Average: 33.876  Curr best: 0.341 [X, Y] = 0.626 0.927
# -------------------------
# Generation:  17  Average: 5.314  Curr best: 0.341 [X, Y] = 0.626 0.927
# -------------------------
# Generation:  18  Average: 19.430  Curr best: 0.341 [X, Y] = 0.626 0.927
# -------------------------
# Generation:  19  Average: 32.551  Curr best: 0.341 [X, Y] = 0.626 0.927
# -------------------------
# Generation:  20  Average: 21.082  Curr best: 0.341 [X, Y] = 0.626 0.927
# -------------------------
# Generation:  21  Average: 35.334  Curr best: 0.341 [X, Y] = 0.626 0.927
# -------------------------
# Generation:  22  Average: 28.909  Curr best: 0.341 [X, Y] = 0.626 0.927
# -------------------------
# Generation:  23  Average: 8.866  Curr best: 0.322 [X, Y] = 0.660 0.653
# -------------------------
# Generation:  24  Average: 19.051  Curr best: 0.322 [X, Y] = 0.660 0.653
# -------------------------
# Generation:  25  Average: 10.049  Curr best: 0.300 [X, Y] = 0.660 0.712
# -------------------------
# Generation:  26  Average: 21.028  Curr best: 0.243 [X, Y] = 1.022 0.653
# -------------------------
# Generation:  27  Average: 8.444  Curr best: 0.243 [X, Y] = 1.022 0.653
# -------------------------
# Generation:  28  Average: 7.044  Curr best: 0.243 [X, Y] = 1.022 0.653
# -------------------------
# Generation:  29  Average: 40.922  Curr best: 0.243 [X, Y] = 1.022 0.653
# -------------------------
# Generation:  30  Average: 5.600  Curr best: 0.094 [X, Y] = 1.017 0.809
# -------------------------
# Generation:  31  Average: 12.165  Curr best: 0.094 [X, Y] = 1.017 0.809
# -------------------------
# Generation:  32  Average: 4.275  Curr best: 0.094 [X, Y] = 1.017 0.809
# -------------------------
# Generation:  33  Average: 18.349  Curr best: 0.094 [X, Y] = 1.017 0.809
# -------------------------
# Generation:  34  Average: 31.080  Curr best: 0.094 [X, Y] = 1.017 0.809
# -------------------------
# Generation:  35  Average: 6.407  Curr best: 0.078 [X, Y] = 1.017 0.829
# -------------------------
# Generation:  36  Average: 22.994  Curr best: 0.078 [X, Y] = 1.017 0.829
# -------------------------
# Generation:  37  Average: 22.548  Curr best: 0.078 [X, Y] = 1.017 0.829
# -------------------------
# Generation:  38  Average: 44.687  Curr best: 0.078 [X, Y] = 1.017 0.829
# -------------------------
# Generation:  39  Average: 11.304  Curr best: 0.026 [X, Y] = 1.017 0.985
# -------------------------
#
# Solution found ! Chromosome content: [X, Y] = 1.017 0.985
#
#
#  5 : run of genetic algorithm with  20  chromosomes.
#
# Generation:  1  Average: 84.941  Curr best: 7.444 [X, Y] = -1.573 0.660
# -------------------------
# Generation:  2  Average: 32.124  Curr best: 7.435 [X, Y] = -1.574 0.660
# -------------------------
# Generation:  3  Average: 36.418  Curr best: 7.435 [X, Y] = -1.574 0.660
# -------------------------
# Generation:  4  Average: 22.769  Curr best: 7.316 [X, Y] = -1.603 0.660
# -------------------------
# Generation:  5  Average: 20.152  Curr best: 5.612 [X, Y] = -1.293 0.660
# -------------------------
# Generation:  6  Average: 32.763  Curr best: 2.989 [X, Y] = -0.668 0.660
# -------------------------
# Generation:  7  Average: 16.087  Curr best: 2.135 [X, Y] = -0.363 0.660
# -------------------------
# Generation:  8  Average: 33.835  Curr best: 2.135 [X, Y] = -0.363 0.660
# -------------------------
# Generation:  9  Average: 17.070  Curr best: 2.135 [X, Y] = -0.363 0.660
# -------------------------
# Generation:  10  Average: 20.317  Curr best: 2.081 [X, Y] = -0.101 0.660
# -------------------------
# Generation:  11  Average: 12.898  Curr best: 1.989 [X, Y] = -0.336 0.660
# -------------------------
# Generation:  12  Average: 14.257  Curr best: 1.914 [X, Y] = -0.087 0.660
# -------------------------
# Generation:  13  Average: 11.477  Curr best: 1.487 [X, Y] = -0.048 0.660
# -------------------------
# Generation:  14  Average: 25.633  Curr best: 1.487 [X, Y] = -0.048 0.660
# -------------------------
# Generation:  15  Average: 17.246  Curr best: 1.487 [X, Y] = -0.048 0.660
# -------------------------
# Generation:  16  Average: 21.610  Curr best: 1.486 [X, Y] = -0.048 0.953
# -------------------------
# Generation:  17  Average: 18.762  Curr best: 1.486 [X, Y] = -0.048 0.953
# -------------------------
# Generation:  18  Average: 17.291  Curr best: 1.486 [X, Y] = -0.048 0.953
# -------------------------
# Generation:  19  Average: 11.706  Curr best: 1.486 [X, Y] = -0.048 0.953
# -------------------------
# Generation:  20  Average: 9.977  Curr best: 1.486 [X, Y] = -0.048 0.953
# -------------------------
# Generation:  21  Average: 22.110  Curr best: 1.486 [X, Y] = -0.048 0.953
# -------------------------
# Generation:  22  Average: 9.306  Curr best: 1.486 [X, Y] = -0.048 0.953
# -------------------------
# Generation:  23  Average: 5.183  Curr best: 1.486 [X, Y] = -0.048 0.953
# -------------------------
# Generation:  24  Average: 15.304  Curr best: 1.486 [X, Y] = -0.048 0.953
# -------------------------
# Generation:  25  Average: 4.774  Curr best: 1.486 [X, Y] = -0.048 0.953
# -------------------------
# Generation:  26  Average: 19.697  Curr best: 1.486 [X, Y] = -0.048 0.953
# -------------------------
# Generation:  27  Average: 3.924  Curr best: 1.332 [X, Y] = -0.048 1.022
# -------------------------
# Generation:  28  Average: 10.951  Curr best: 1.332 [X, Y] = -0.048 1.022
# -------------------------
# Generation:  29  Average: 4.031  Curr best: 1.332 [X, Y] = -0.048 1.022
# -------------------------
# Generation:  30  Average: 13.942  Curr best: 1.332 [X, Y] = -0.048 1.022
# -------------------------
# Generation:  31  Average: 4.052  Curr best: 1.170 [X, Y] = -0.028 1.022
# -------------------------
# Generation:  32  Average: 8.637  Curr best: 1.170 [X, Y] = -0.028 1.022
# -------------------------
# Generation:  33  Average: 7.197  Curr best: 1.170 [X, Y] = -0.028 1.022
# -------------------------
# Generation:  34  Average: 24.480  Curr best: 1.170 [X, Y] = -0.028 1.022
# -------------------------
# Generation:  35  Average: 10.974  Curr best: 1.170 [X, Y] = -0.028 1.022
# -------------------------
# Generation:  36  Average: 2.425  Curr best: 1.170 [X, Y] = -0.028 1.022
# -------------------------
# Generation:  37  Average: 24.453  Curr best: 1.170 [X, Y] = -0.028 1.022
# -------------------------
# Generation:  38  Average: 24.478  Curr best: 1.170 [X, Y] = -0.028 1.022
# -------------------------
# Generation:  39  Average: 26.537  Curr best: 1.170 [X, Y] = -0.028 1.022
# -------------------------
# Generation:  40  Average: 6.985  Curr best: 1.170 [X, Y] = -0.028 1.022
# -------------------------
# Generation:  41  Average: 15.062  Curr best: 1.170 [X, Y] = -0.028 1.022
# -------------------------
# Generation:  42  Average: 24.876  Curr best: 1.170 [X, Y] = -0.028 1.022
# -------------------------
# Generation:  43  Average: 10.579  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  44  Average: 9.146  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  45  Average: 33.115  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  46  Average: 2.420  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  47  Average: 16.417  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  48  Average: 13.129  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  49  Average: 21.434  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  50  Average: 8.241  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  51  Average: 16.160  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  52  Average: 15.221  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  53  Average: 6.310  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  54  Average: 12.022  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  55  Average: 5.920  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  56  Average: 19.822  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  57  Average: 11.518  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  58  Average: 13.229  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  59  Average: 13.761  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  60  Average: 8.078  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  61  Average: 14.304  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  62  Average: 5.524  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  63  Average: 4.465  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
# Generation:  64  Average: 4.513  Curr best: 1.153 [X, Y] = -0.028 0.983
# -------------------------
#
# Stopped due to convergance.Best chromosome [X, Y] = -0.028 0.983
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-f84653883804> in <module>()
#      14     genetic(levy_function, [10, -10], x)
#      15
# ---> 16   display_stats(all_avg_list, all_best_list, generations_list)
#      17   all_best_list = []
#      18   all_avg_list = []
#
# NameError: name 'display_stats' is not defined
